# %%
fruits = {"Apple", "Banana"}
fruits.add("orange")
print("fruits:", fruits)
fruits.pop()
print(fruits)
fruits.remove("Apple")
print("fruits:",fruits)
# Out:
# fruits: {'orange', 'Banana', 'Apple'}
# {'Banana', 'Apple'}
# fruits: {'Banana'}

# %%
student = {
    "name": "Amara Mensah", 
           "id":10245, 
           "gpa": 3.8, 
           }
print(student)
print(student["name"])
print(student["id"])
print(student["gpa"])
print(student.get("enrolled", "not enrolled"))
# Out:
# {'name': 'Amara Mensah', 'id': 10245, 'gpa': 3.8}
# Amara Mensah
# 10245
# 3.8
# not enrolled

# %%
student = {"email": "rayo@gmail.com",
"phone_num": "8028918499",
"matric_num": "2345"}
print(student)
print(student["email"])
print(student["phone_num"])
print(student["matric_num"])
print(student.get("enrolled","not enrolled"))
# Out:
# {'email': 'rayo@gmail.com', 'phone_num': '8028918499', 'matric_num': '2345'}
# rayo@gmail.com
# 8028918499
# 2345
# not enrolled

# %%
# MINI PROJECT: Python Identity Card
#user information

full_name = input("Enter your full name: ")
age = int(input("Enter your age: "))
country = input("Enter your country: ")
focus_area = input("Enter your focus area: ")
course_goal = input("Enter your course goal: ")
print("=" * 80)
print("=" * 80)
print(f"                IDENTITY CARD")
print(f" Name: {full_name}")
print(f" Age: {age}")
print(f" Country: {country}")
print(f" Focus Area: {focus_area}")
print(f" Course Goal: {course_goal}")
print("-" *80)
print(f"    Every expert was once a beginer, keep learning and growing!")
print("=" *80)
# Out:
# ================================================================================
# ================================================================================
#                 IDENTITY CARD
#  Name: Motunrayo Mariam
#  Age: 27
#  Country: Nigeria
#  Focus Area: Data Science
#  Course Goal: Gain relevant skills in data science and solve real-time problems.
# --------------------------------------------------------------------------------
#     Every expert was once a beginer, keep learning and growing!
# ================================================================================

# %%
#dataset structure
data_set ={
    "Ai" : {"Fola","Amaka","Jola"}, 
    "python": {"Funmi", "Jola", "Mercy}"}}

#add two new students
data_set["Ai"].add("Timi")
data_set["Ai"].add("Jimi")

# get intersection and difference of course a and b
student_in_both = data_set["Ai"].intersection(data_set["python"])
only_Ai = data_set["Ai"].difference(data_set["python"])

print(data_set)
print(student_in_both)
print(only_Ai)

print("-" * 20)
print("solution 4")
print("-" * 20)
# Out:
# {'Ai': {'Timi', 'Jola', 'Fola', 'Amaka', 'Jimi'}, 'python': {'Funmi', 'Jola', 'Mercy}'}}
# {'Jola'}
# {'Amaka', 'Timi', 'Fola', 'Jimi'}
# --------------------
# solution 4
# --------------------

# %%
def greet():
    print("Hello, welcome to python")
    print("Let's write some functions.")
greet()
def never_called():
    print("I will never run unless called")
never_called()
def come_eat():
    print("food is ready!")
come_eat()
# Out:
# Hello, welcome to python
# Let's write some functions.
# I will never run unless called
# food is ready!

# %%
def arithmetic():
    print(7 + 8)
    print(3 * 7)
    print(28 / 4)
arithmetic()
# Out:
# 15
# 21
# 7.0

# %%
def Get_day(day):
    print("Today is", (day))
Get_day("Thursday")
# Out:
# Today is Thursday

# %%
def area_rectangle(a, b):
    rectangle = a * b
    print(" the area is", rectangle)
area_rectangle(4, 7)
# Out:
#  the area is 28
